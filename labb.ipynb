# %% [markdown]
# <a href="https://colab.research.google.com/github/aakankshyaojha/Data_Communication/blob/main/labb.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#comments
#single line
print("hello! lets learn python fundamentals!")
"""this is a multiple line comment(also called docsstring)
"""
# Out:
# hello! lets learn python fundamentals!
# 'this is a multiple line comment(also called docsstring)\n'

# %%
#variable and data types

print("variable and data types")
# Out:
# variable and data types

# %%
name="aaku"
message="python is fun!"
#boolean
is_student=True
has_job=False

#display variables and their types
print(f"Name: {name}(type:{type(name)})")
print(f"Is student: {is_student}(type:{type(is_student)})")


#type conversion
print("type conversion")


print(f"converting {age}to float:{num_float}")
# Out:
# Name: janaka(type:<class 'str'>)
# Is student: True(type:<class 'bool'>)
# type conversion
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_804/2241893153.py in <cell line: 0>()
#      14
#      15
# ---> 16 print(f"converting {age}to float:{num_float}")
#
# NameError: name 'age' is not defined

# %%
#string to integer
age=82
num_str="100"
num_int=int(num_str)
print(f"converting {age}to float:{num_str}")
# Out:
# converting 82to float:100

# %%
#integer to float
num_float=float(age)
print(f"converting {age}to string:{num_float}")
# Out:
# converting 82to string:82.0

# %%
#float to integer(truncates decimal)
pi=3.14159
pi_int=int(pi)
print(f"converting {pi}to string:{pi_int}")
# Out:
# converting 3.14159to string:3

# %%
#string concatination
greeting = "Hello"
name = "Aayush"

combined = greeting + " " + name

print(f"Concatenation: {combined}")

#string repetion
laugh="ha"*3
print(f"repetitio:{laugh}")


#string method
text="python programmming"
print(f"original:'{text}'")
print(f"strip whitespaces:''{text.strip()}'")
print(f"uppercase:'{text.upper()}")
print(f"lowercase:'{text.lower()}")
print(f"Replace:{text.replace('python','java')}")
print(f"split:{text.split()}")
#string formatting
name="charlie"
score=95
print(f"student:{name},score:{score}")



#strinf slicing
word="programming"
print(f"word:{word}")
print(f"reverse:{word[::-1]}")
# Out:
# Concatenation: Hello Aayush
# repetitio:hahaha
# original:'python programmming'
# strip whitespaces:''python programmming'
# uppercase:'PYTHON PROGRAMMMING
# lowercase:'python programmming
# Replace:java programmming
# split:['python', 'programmming']
# student:charlie,score:95
# word:programming
# reverse:gnimmargorp

# %%
#arthmetic operation
a=10
b=3
print(f"a={a},b={b}")
print(f"addition:{a}+{b}={a+b}")
print(f"subtraction:{a}-{b}={a-b}")
print(f"multiplication:{a}*{b}={a*b}")


# Variables
a = 10
b = 3
